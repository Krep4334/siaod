# %% [markdown]
# # Лабораторная работа №2
# ## Выполнил студент группы Самодуров Никита Серегеевич БПИ2303

# %% [markdown]
# ### Задание №1
# Отсортировать строки файла, содержащие названия книг, в алфавитном порядке с использованием двух деков.

# %%
from collections import deque

def sort_books(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        books = deque(file.readlines())
    
    sorted_books = deque()
    while books:
        book = books.popleft()
        while sorted_books and sorted_books[-1] > book:
            books.appendleft(sorted_books.pop())
        sorted_books.append(book)
    
    with open('sorted_books.txt', 'w', encoding='utf-8') as file:
        file.writelines(sorted_books)
    
    print("Отсортированные книги:")
    print(''.join(sorted_books))

sort_books('books.txt')
# Out:
# Отсортированные книги:
# 1984Анна Каренина
# Война и мир
# Гордость и предубеждение
# Мастер и Маргарита
# Преступление и наказание

# %% [markdown]
# ### Задание №2
# Дек содержит последовательность символов для шифровки сообщений. Дан текстовый файл, содержащий зашифрованное сообщение. Пользуясь деком, расшифровать текст.
# Известно, что при шифровке каждый символ сообщения заменялся следующим за ним в деке по часовой стрелке через один.

# %%
from collections import deque

def decrypt_message(filename, cipher_deque):
    with open(filename, 'r', encoding='utf-8') as file:
        encrypted_text = file.read()
    
    decrypted_text = ''
    for char in encrypted_text:
        if char in cipher_deque:
            index = cipher_deque.index(char)
            decrypted_text += cipher_deque[index - 1]
        else:
            decrypted_text += char
    
    with open('decrypted_message.txt', 'w', encoding='utf-8') as file:
        file.write(decrypted_text)
    
    print("Расшифрованный текст:")
    print(decrypted_text)

decrypt_message('encrypted_message.txt', deque('ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789'))
# Out:
# Расшифрованный текст:
# The!secret!apple!

# %% [markdown]
# ### Задание №3
# Даны три стержня и n дисков различного размера. Диски можно надевать на стержни, образуя из них башни. Перенести n дисков со стержня А на стержень С, сохранив их первоначальный порядок. При переносе дисков необходимо соблюдать следующие правила:
# - на каждом шаге со стержня на стержень переносить только один диск;
# - диск нельзя помещать на диск меньшего размера;
# - для промежуточного хранения можно использовать стержень В.
# Реализовать алгоритм, используя три стека вместо стержней А, В, С. Информация о дисках хранится в исходном файле.

# %%
def hanoi_tower(n, source, auxiliary, target):
    if n > 0:
        hanoi_tower(n - 1, source, target, auxiliary)
        target.append(source.pop())
        hanoi_tower(n - 1, auxiliary, source, target)

def solve_hanoi(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        disks = list(map(int, file.readlines()))
    
    A, B, C = disks[::-1], [], [] 
    hanoi_tower(len(disks), A, B, C)
    
    with open('hanoi_result.txt', 'w', encoding='utf-8') as file:
        file.writelines(f"{disk}\n" for disk in C)
    
    print("Результат перестановки:")
    print(C)

solve_hanoi('hanoi_disks.txt')
# Out:
# Результат перестановки:
# [1, 2, 3]

# %% [markdown]
# ### Задание №4
# Дан текстовый файл с программой на алгоритмическом языке. За один просмотр файла проверить баланс круглых скобок в тексте, используя стек.

# %%
def check_parentheses(filename):
    stack = []
    with open(filename, 'r', encoding='utf-8') as file:
        for line in file:
            for char in line:
                if char == '(':
                    stack.append(char)
                elif char == ')':
                    if not stack:
                        print("Несбалансированные скобки")
                        return
                    stack.pop()
    print("Скобки сбалансированы" if not stack else "Несбалансированные скобки")

check_parentheses('program_parentheses.txt')
# Out:
# Несбалансированные скобки

# %% [markdown]
# ### Задание №5
# Дан текстовый файл с программой на алгоритмическом языке. За один просмотр файла проверить баланс квадратных скобок в тексте, используя дек.

# %%
from collections import deque

def check_square_brackets(filename):
    deque_brackets = deque()
    with open(filename, 'r', encoding='utf-8') as file:
        for line in file:
            for char in line:
                if char == '[':
                    deque_brackets.append(char)
                elif char == ']':
                    if not deque_brackets:
                        print("Несбалансированные скобки")
                        return
                    deque_brackets.pop()
    print("Скобки сбалансированы" if not deque_brackets else "Несбалансированные скобки")

check_square_brackets('program_square_brackets.txt')
# Out:
# Скобки сбалансированы

# %% [markdown]
# ### Задание №6
# Дан файл из символов. Используя стек, за один просмотр файла напечатать сначала все цифры, затем все буквы, и, наконец, все остальные символы, сохраняя исходный порядок в каждой группе символов.

# %%
def group_characters(filename):
    digits, letters, others = [], [], []
    with open(filename, 'r', encoding='utf-8') as file:
        for char in file.read():
            if char.isdigit():
                digits.append(char)
            elif char.isalpha():
                letters.append(char)
            else:
                others.append(char)
    
    result = ''.join(digits + letters + others)
    with open('grouped_characters.txt', 'w', encoding='utf-8') as file:
        file.write(result)
    print("Результат группировки:")
    print(result)
group_characters('characters.txt')
# Out:
# Результат группировки:
# 19427qhdqnq!@@#!

# %% [markdown]
# ### Задание №7
# Дан файл из целых чисел. Используя дек, за один просмотр файла напечатать сначала все отрицательные числа, затем все положительные числа, сохраняя исходный порядок в каждой группе.

# %%
from collections import deque

def group_numbers(filename):
    deque_numbers = deque()
    with open(filename, 'r', encoding='utf-8') as file:
        for number in map(int, file.readlines()):
            if number < 0:
                deque_numbers.appendleft(number)
            else:
                deque_numbers.append(number)
    
    with open('grouped_numbers.txt', 'w', encoding='utf-8') as file:
        file.writelines(f"{num}\n" for num in deque_numbers)
    print("Результат группировки чисел:")
    print(list(deque_numbers))

group_numbers('numbers.txt')
# Out:
# Результат группировки чисел:
# [-3, -1, 2, 4]

# %% [markdown]
# ### Задание №8
# Дан текстовый файл. Используя стек, сформировать новый текстовый файл, содержащий строки исходного файла, записанные в обратном порядке: первая строка становится последней, вторая – предпоследней и т.д.

# %%
def reverse_lines(filename):
    stack = []
    with open(filename, 'r', encoding='utf-8') as file:
        stack.extend(file.readlines())
    
    with open('reversed_lines.txt', 'w', encoding='utf-8') as file:
        file.writelines(reversed(stack))
    print("Результат переворота строк:")
    print(''.join(reversed(stack)))

reverse_lines('lines.txt')
# Out:
# Результат переворота строк:
# Третья строка
# Вторая строка
# Первая строка
